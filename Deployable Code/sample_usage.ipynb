# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from utils import read_image
from model import build_model
from inference import inference 

weights_path = '/content/drive/MyDrive/27_Case_study_2/best_Double_Unet.hdf5'
inf = inference(weights_path)
image_path = '/content/1.2.276.0.7230010.3.1.4.8323329.1000.1517875165.878027.png'
inf.Predict(image_path, plot=True)
